# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("Bengaluru_House_Data.csv")

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  str
#  1   availability  13320 non-null  str
#  2   location      13319 non-null  str
#  3   size          13304 non-null  str
#  4   society       7818 non-null   str
#  5   total_sqft    13320 non-null  str
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), str(6)
# memory usage: 936.7 KB

# %%
data.isna().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
print(f"Rows:{data.shape[0]},Columns:{data.shape[1]}")
data.groupby('area_type')['area_type'].agg('count')
# Out:
# Rows:13320,Columns:9
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
# Drop columns that are not useful for price prediction
data=data.drop(['area_type','society','balcony','availability'],axis='columns')
# print("Shape after dropping columns:",data.shape)
data.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
data.describe()
# Out:
#                bath         price
# count  13247.000000  13320.000000
# mean       2.692610    112.565627
# std        1.341458    148.971674
# min        1.000000      8.000000
# 25%        2.000000     50.000000
# 50%        2.000000     72.000000
# 75%        3.000000    120.000000
# max       40.000000   3600.000000

# %%
data['location'].value_counts()
# Out:
# location
# Whitefield                                         540
# Sarjapur  Road                                     399
# Electronic City                                    302
# Kanakpura Road                                     273
# Thanisandra                                        234
#                                                   ...
# Pattegarhpalya                                       1
# Tilak Nagar                                          1
# 12th cross srinivas nagar banshankari 3rd stage      1
# Havanur extension                                    1
# Abshot Layout                                        1
# Name: count, Length: 1305, dtype: int64

# %%
data['location']=data['location'].fillna('Sarjapur Road')

# %%
data['size'].value_counts()
# Out:
# size
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 BHK           2
# 11 Bedroom       2
# 10 BHK           2
# 27 BHK           1
# 19 BHK           1
# 16 BHK           1
# 43 Bedroom       1
# 14 BHK           1
# 12 Bedroom       1
# 13 BHK           1
# 18 Bedroom       1
# Name: count, dtype: int64

# %%
# 1. Drop missing values first
data=data.dropna()
# 2. Create a new column 'bhk' by taking the first number from 'size'
# lambda x: int(x.split(' ')[0]) takes "2 BHK", splits it into ["2", "BHK"], and keeps "2"
data['bhk']=data['size'].apply(lambda x:int(x.split(' ')[0]))
# Check if it worked
print(data['bhk'].unique())
data.head()
# Out:
# [ 2  4  3  6  1  8  7  5 11  9 27 10 19 16 43 14 12 13 18]
#                    location       size total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                  Kothanur      2 BHK       1200   2.0   51.00    2

# %%
#The Hard Part (Fixing total_sqft)
def convert_sqft_to_num(x):
    tokens=x.split('-')
    if len(tokens)==2:
        # If it's a range like "1000 - 2000", take the average
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None
# Apply this function to the dataset
data=data.copy()
data['total_sqft']=data['total_sqft'].apply(convert_sqft_to_num)
# Remove the rows where total_sqft became None (the garbage rows)
data = data.dropna()
print("Cleaned Data Shape:",data.shape)
data.head()
# Out:
# Cleaned Data Shape: (13201, 6)
#                    location       size  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2

# %%
# Let's check a specific row that used to be a range
# (Row index 30 in this dataset is usually a range)
print(data.loc[30])
# Out:
# location      Yelahanka
# size              4 BHK
# total_sqft       2475.0
# bath                4.0
# price             186.0
# bhk                   4
# Name: 30, dtype: object

# %% [markdown]
# Price per sq_feet

# %%
# Create price_per_sqft column (Price is in Lakhs, so multiply by 100,000)
data = data.copy()
data['price_per_sqft'] = data['price']*100000/data['total_sqft']
data.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0     3699.810606
# 1     4615.384615
# 2     4305.555556
# 3     6245.890861
# 4     4250.000000

# %%
# 1. Strip extra spaces from location names
data.location = data.location.apply(lambda x: x.strip())

# 2. Count how many rows exist for each location
location_stats = data.groupby('location')['location'].agg('count').sort_values(ascending=False)
print(location_stats)

# 3. Identify locations with less than 10 data points
location_stats_less_than_10 = location_stats[location_stats <= 10]

# 4. Group them into "other"
data.location = data.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)

# Check the new number of unique locations (Should be much smaller, around 240)
print(len(data.location.unique()))
# Out:
# location
# Whitefield               533
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           264
# Thanisandra              235
#                         ...
# Kanakapura Road            1
# 1 Giri Nagar               1
# Kanakapura main  Road      1
# Kannur                     1
# whitefiled                 1
# Name: location, Length: 1288, dtype: int64
# 241

# %%
# Check for rows where sqft per bedroom is < 300 (Impossible houses)
print(data[data.total_sqft/data.bhk < 300].head())

# Remove them
data = data[~(data.total_sqft/data.bhk < 300)]
print("Shape after removing outliers:", data.shape)
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 45           HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 58        Murugeshpalya  6 Bedroom      1407.0   4.0  150.0    6
# 68  Devarachikkanahalli  8 Bedroom      1350.0   7.0   85.0    8
# 70                other  3 Bedroom       500.0   3.0  100.0    3
#
#     price_per_sqft
# 9     36274.509804
# 45    33333.333333
# 58    10660.980810
# 68     6296.296296
# 70    20000.000000
# Shape after removing outliers: (12457, 7)

# %% [markdown]
# Outlier Removal(standard deviation)

# %%
def remove_pps_outliers(df):
    df_out=pd.DataFrame()
    for key,subdf in df.groupby('location'):
        m=np.mean(subdf.price_per_sqft)
        st=np.std(subdf.price_per_sqft)
        reduced_df=subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_out=pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

data=remove_pps_outliers(data)
print("Shape after removing extreme price outliers:", data.shape)
# Out:
# Shape after removing extreme price outliers: (10243, 7)

# %%
def bhk_outlier_remover(df):
    exclude_indices=np.array([])
    for location,location_df in df.groupby('location'):
        bhk_stats={}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk]={
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats=bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices=np.append(exclude_indices,bhk_df[bhk_df.price_per_sqft<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')

# %%
data=bhk_outlier_remover(data)

# %%
data.shape
# Out:
# (7318, 7)

# %%
data.to_csv("cleaned_data.csv", index=False)
